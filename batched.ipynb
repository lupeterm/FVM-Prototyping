# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter, NullFormatter, ScalarFormatter
import numpy as np
import pandas as pd
import seaborn as sb
import seaborn.objects as so

all = pd.read_csv("corr.csv", skip_blank_lines=True)
ldc = pd.read_csv("corr2.csv", skip_blank_lines=True)
ldc2 = pd.read_csv("corr3.csv", skip_blank_lines=True)

# %%
all
# Out:
#     blocksize  workgroupsize      time
# 0           2              2  0.038375
# 1           2              4  0.023528
# 2           2              8  0.018619
# 3           2             16  0.017435
# 4           2             32  0.016664
# ..        ...            ...       ...
# 95       1024             64  0.028268
# 96       1024            128  0.028564
# 97       1024            256  0.028285
# 98       1024            512  0.030404
# 99       1024           1024  0.030529
#
# [100 rows x 3 columns]

# %%
pivot_df = all.pivot(index='blocksize', columns='workgroupsize', values='time')
ldcpivot_df = ldc.pivot(index='blocksize', columns='workgroupsize', values='time')
ldc2pivot_df = ldc2.pivot(index='blocksize', columns='workgroupsize', values='time')

# %%
f, axes = plt.subplots(2,2, figsize=(15, 20))
wb = axes.flat[0]
ldc = axes.flat[1]
ldc2 = axes.flat[2]
p1 = sb.heatmap(pivot_df,annot=True, square=True, ax = wb)  # no color specified
p1.set(title="Windsorbody, merged")
p2 = sb.heatmap(ldcpivot_df,annot=True, square=True, ax = ldc)  # no color specified
p2.set(title="LDC, merged")
p3 = sb.heatmap(ldc2pivot_df,annot=True, square=True, ax = ldc2)  # no color specified
p3.set(title="LDC, default")
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter, NullFormatter, ScalarFormatter
import numpy as np
import pandas as pd
import seaborn as sb
import seaborn.objects as so
import math


df = pd.read_csv("test.csv", skip_blank_lines=True)
df["cells"] = [int(x.rsplit("/", 2)[1])**3 for x in df["case_long"]]
df["ms_normed"] = df["time_mean_ms"] / df["cells"]
strategies = list(df["strategy"].unique())


sb.set_theme()

# %%
plot = sb.relplot(data=df, x="cells", kind="line", y="time_mean_ms")
plot.set(title="Assembly Time")
plot = sb.relplot(data=df, x="cells", kind="scatter", y="ms_normed")
plot.set(title="Assembly Time Normed Per Cell")

# %%
plot = sb.relplot(data=df, x="cells", kind="scatter", y="ms_normed")
plot.set(title="Assembly Time per Cell")
axes = plot.axes.flat

# %%
df
# Out:
#    time_mean_ms  time_median_ms  gc_time_mean_ms  gc_time_median_ms  \
# 0      0.022663        0.022463              0.0                0.0
# 1      0.045410        0.043822              0.0                0.0
# 2      0.200876        0.199612              0.0                0.0
# 3      0.443145        0.441429              0.0                0.0
# 4      0.841252        0.837693              0.0                0.0
# 5      1.436858        1.429983              0.0                0.0
# 6      2.345619        2.341144              0.0                0.0
# 7      3.478369        3.476851              0.0                0.0
# 8      4.955488        4.947622              0.0                0.0
# 9      6.802695        6.794931              0.0                0.0
#
#                        case_short                       case_long  \
# 0   cases/Lid-Driven-Cavities/20/   cases/Lid-Driven-Cavities/20/
# 1   cases/Lid-Driven-Cavities/40/   cases/Lid-Driven-Cavities/40/
# 2   cases/Lid-Driven-Cavities/60/   cases/Lid-Driven-Cavities/60/
# 3   cases/Lid-Driven-Cavities/80/   cases/Lid-Driven-Cavities/80/
# 4  cases/Lid-Driven-Cavities/100/  cases/Lid-Driven-Cavities/100/
# 5  cases/Lid-Driven-Cavities/120/  cases/Lid-Driven-Cavities/120/
# 6  cases/Lid-Driven-Cavities/140/  cases/Lid-Driven-Cavities/140/
# 7  cases/Lid-Driven-Cavities/160/  cases/Lid-Driven-Cavities/160/
# 8  cases/Lid-Driven-Cavities/180/  cases/Lid-Driven-Cavities/180/
# 9  cases/Lid-Driven-Cavities/200/  cases/Lid-Driven-Cavities/200/
#
#       strategy                variant language precision executor  \
# 0  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
# 1  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
# 2  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
# 3  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
# 4  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
# 5  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
# 6  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
# 7  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
# 8  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
# 9  batchedFace  NonGroupedFusedDivLap    julia   float64      gpu
#
#    use_kernelAbstractions  use_fusing    cells     ms_normed
# 0                    True        True     8000  2.832881e-06
# 1                    True        True    64000  7.095262e-07
# 2                    True        True   216000  9.299798e-07
# 3                    True        True   512000  8.655175e-07
# 4                    True        True  1000000  8.412522e-07
# 5                    True        True  1728000  8.315148e-07
# 6                    True        True  2744000  8.548173e-07
# 7                    True        True  4096000  8.492112e-07
# 8                    True        True  5832000  8.497064e-07
# 9                    True        True  8000000  8.503369e-07
